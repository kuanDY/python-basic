# %% [markdown]
# # playdata_21 (2)

# %% [markdown]
# * while 반복문

# %%
a = 1
while a < 10:
    #a = a + 1
    #a += 1
    a *= 2
    print (a)
# Out:
# 2
# 4
# 8
# 16

# %% [markdown]
# * 개행문자 -> \n (이스케이프 문자)

# %%
for x in range(20):
    if x % 2 == 0:
        print("실행?")
        if False:
            break
        # continue
        # break
        print(x , end = ", ")
    else:
        print("홀수")
# Out:
# 실행?
# 0, 홀수
# 실행?
# 2, 홀수
# 실행?
# 4, 홀수
# 실행?
# 6, 홀수
# 실행?
# 8, 홀수
# 실행?
# 10, 홀수
# 실행?
# 12, 홀수
# 실행?
# 14, 홀수
# 실행?
# 16, 홀수
# 실행?
# 18, 홀수

# %% [markdown]
# 메뉴얼 확인하는 법

# %%
str = "Hello"
help(str.find)
# Out:
# Help on built-in function find:
#
# find(...) method of builtins.str instance
#     S.find(sub[, start[, end]]) -> int
#
#     Return the lowest index in S where substring sub is found,
#     such that sub is contained within S[start:end].  Optional
#     arguments start and end are interpreted as in slice notation.
#
#     Return -1 on failure.

# %%
import requests
url = "https://www.naver.com/"
r = requests.get(url)
r.text
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네
# ...

# %%
os.getcwd
# Out:
# <function nt.getcwd()>

# %%
import os
os.getcwd()
# 상대경로 지정
f = open("C:\\workspace\\test1.html", "r", encoding='utf-8') #<-tip) 경로 쓸 때 \이것보단 \\두번 쓰는게 더 좋음
# 한글의 인코딩 : euc-kr, cp949, utf-8
text = f.read()
print(text)
# Out:
# <!DOCTYPE html>
# <head>
#     <title>하하하</title>
#
# </head>
# <body>
#     배고픔?
#     <h1> 제목 1</h1>
#     <h2> 제목 1</h2>
#     <h3> 제목 1</h3>
#     <h4> 제목 1</h4>
#     <li>데이터 1</li>
#     <li>데이터 2</li>
#
#     <div style="color: aqua;">
#     <li>데이터 3<a href="https://daum.net">클릭</a></li>
#     <p>데이터 분석을 위한 파이썬 철저 입문 <br> ㅎㅎㅎㅎ</p>
#     </div>
# </body>
#
# </html>

# %%
from bs4 import BeautifulSoup  # 파싱하는 기능을 가지고 있다
bs = BeautifulSoup(text)
bs.find("p").text
# Out:
# '데이터 분석을 위한 파이썬 철저 입문  ㅎㅎㅎㅎ'

# %%
for x in bs.findAll("li"):
    print(x.text)
# Out:
# 데이터 1
# 데이터 2
# 데이터 3클릭

# %%
bs.find('a').text.strip()
# Out:
# '클릭'

# %%
bs.find('a')['href']
# Out:
# 'https://daum.net'

# %%
head = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36"
}
r = requests.get("https://www.melon.com/song/detail.htm?songId=34819473",headers=head)

# %%
bs = BeautifulSoup(r.text)
lyric = bs.find("div", id = "d_video_summary")

# %%
lyric
# Out:
# <div class="lyric" id="d_video_summary"><!-- height:auto; 로 변경시, 확장됨 -->
# ...

# %%
print(BeautifulSoup(str(lyric).replace("<br/>", "\n")).text.strip())
# Out:
# 생각이 많은 건 말이야
# 당연히 해야 할 일이야
# 나에겐 우리가 지금 1순위야
# 안전한 유리병을 핑계로
# 바람을 가둬 둔 것 같지만
#
# 기억나? 그날의 우리가
# 잡았던 그 손엔 말이야
# 설레임보다 커다란 믿음이 담겨서
# 난 함박웃음을 지었지만
# 울음이 날 것도 같았어
# 소중한 건 언제나 두려움이니까
#
# 문을 열면 들리던 목소리
# 너로 인해 변해있던 따뜻한 공기
# 여전히 자신 없지만 안녕히
#
# 저기, 사라진 별의 자리
# 아스라이 하얀 빛
# 한동안은 꺼내 볼 수 있을 거야
# 아낌없이 반짝인 시간은
# 조금씩 옅어져 가더라도
# 너와 내 맘에 살아 숨 쉴 테니
#
#
# 여긴, 서로의 끝이 아닌
# 새로운 길 모퉁이
# 익숙함에 진심을 속이지 말자
# 하나 둘 추억이 떠오르면
# 많이 많이 그리워할 거야
# 고마웠어요 그래도 이제는
# 사건의 지평선 너머로
#
# 솔직히 두렵기도 하지만
# 노력은 우리에게 정답이 아니라서
# 마지막 선물은 산뜻한 안녕
#
# 저기, 사라진 별의 자리
# 아스라이 하얀 빛
# 한동안은 꺼내 볼 수 있을 거야
# 아낌없이 반짝인 시간은
# 조금씩 옅어져 가더라도
# 너와 내 맘에 살아 숨 쉴 테니
#
# 여긴, 서로의 끝이 아닌
# 새로운 길 모퉁이
# 익숙함에 진심을 속이지 말자
# 하나 둘 추억이 떠오르면
# 많이 많이 그리워할 거야
# 고마웠어요 그래도 이제는
# 사건의 지평선 너머로
#
# 저기, 사라진 별의 자리
# 아스라이 하얀 빛
# 한동안은 꺼내 볼 수 있을 거야
# 아낌없이 반짝인 시간은
# 조금씩 옅어져 가더라도
# 너와 내 맘에 살아 숨 쉴 테니
#
# 여긴, 서로의 끝이 아닌
# 새로운 길 모퉁이
# 익숙함에 진심을 속이지 말자
# 하나 둘 추억이 떠오르면
# 많이 많이 그리워할 거야
# 고마웠어요 그래도 이제는
# 사건의 지평선 너머로
#
# 사건의 지평선 너머로

# %% [markdown]
# 성연코드

# %%
headers = head
response = requests.get('https://www.melon.com/song/detail.htm?songId=34819473', headers=headers)
soup = BeautifulSoup(response.text)
lyrics = soup.find('div', id='d_video_summary')
lyrics = lyrics.get_text(separator='\n', strip=True)
print(lyrics)
# Out:
# 생각이 많은 건 말이야
# 당연히 해야 할 일이야
# 나에겐 우리가 지금 1순위야
# 안전한 유리병을 핑계로
# 바람을 가둬 둔 것 같지만
# 기억나? 그날의 우리가
# 잡았던 그 손엔 말이야
# 설레임보다 커다란 믿음이 담겨서
# 난 함박웃음을 지었지만
# 울음이 날 것도 같았어
# 소중한 건 언제나 두려움이니까
# 문을 열면 들리던 목소리
# 너로 인해 변해있던 따뜻한 공기
# 여전히 자신 없지만 안녕히
# 저기, 사라진 별의 자리
# 아스라이 하얀 빛
# 한동안은 꺼내 볼 수 있을 거야
# 아낌없이 반짝인 시간은
# 조금씩 옅어져 가더라도
# 너와 내 맘에 살아 숨 쉴 테니
# 여긴, 서로의 끝이 아닌
# 새로운 길 모퉁이
# 익숙함에 진심을 속이지 말자
# 하나 둘 추억이 떠오르면
# 많이 많이 그리워할 거야
# 고마웠어요 그래도 이제는
# 사건의 지평선 너머로
# 솔직히 두렵기도 하지만
# 노력은 우리에게 정답이 아니라서
# 마지막 선물은 산뜻한 안녕
# 저기, 사라진 별의 자리
# 아스라이 하얀 빛
# 한동안은 꺼내 볼 수 있을 거야
# 아낌없이 반짝인 시간은
# 조금씩 옅어져 가더라도
# 너와 내 맘에 살아 숨 쉴 테니
# 여긴, 서로의 끝이 아닌
# 새로운 길 모퉁이
# 익숙함에 진심을 속이지 말자
# 하나 둘 추억이 떠오르면
# 많이 많이 그리워할 거야
# 고마웠어요 그래도 이제는
# 사건의 지평선 너머로
# 저기, 사라진 별의 자리
# 아스라이 하얀 빛
# 한동안은 꺼내 볼 수 있을 거야
# 아낌없이 반짝인 시간은
# 조금씩 옅어져 가더라도
# 너와 내 맘에 살아 숨 쉴 테니
# 여긴, 서로의 끝이 아닌
# 새로운 길 모퉁이
# 익숙함에 진심을 속이지 말자
# 하나 둘 추억이 떠오르면
# 많이 많이 그리워할 거야
# 고마웠어요 그래도 이제는
# 사건의 지평선 너머로
# 사건의 지평선 너머로

# %%
chart_url = "https://www.melon.com/chart/index.htm"
r = BeautifulSoup(requests.get(chart_url, headers=head).text).findAll('tr', id="lst50")
print(len(r))
print(r)
# Out:
# 50
# [<tr class="lst50" data-song-no="35945927" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Ditto 곡 선택" type="checkbox" value="35945927"/></div></td>
# <td><div class="wrap t_center"><span class="rank">1</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11127145');" title="NewJeans 'OMG'">
# <img alt="NewJeans 'OMG' - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/111/27/145/11127145_20230102135733_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# ...

# %%
r[0]
# Out:
# <tr class="lst50" data-song-no="35945927" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Ditto 곡 선택" type="checkbox" value="35945927"/></div></td>
# <td><div class="wrap t_center"><span class="rank">1</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11127145');" title="NewJeans 'OMG'">
# <img alt="NewJeans 'OMG' - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/111/27/145/11127145_20230102135733_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# ...

# %%
total = []
os.makedirs("./top100", exist_ok = True)
for _ in BeautifulSoup(requests.get(chart_url, headers=head).text).findAll('tr', id="lst50"):
    total.append(_['data-song-no'])
    print("https://www.melon.com/song/detail.htm?songId={}".format(_['data-song-no']))
for _ in BeautifulSoup(requests.get(chart_url, headers=head).text).findAll('tr', id="lst100"):
    print("https://www.melon.com/song/detail.htm?songId={}".format(_['data-song-no']))
    total.append(_['data-song-no'])
len(total)
# Out:
# https://www.melon.com/song/detail.htm?songId=35945927
# https://www.melon.com/song/detail.htm?songId=35985167
# https://www.melon.com/song/detail.htm?songId=35454426
# https://www.melon.com/song/detail.htm?songId=34819473
# https://www.melon.com/song/detail.htm?songId=36034936
# https://www.melon.com/song/detail.htm?songId=36078777
# https://www.melon.com/song/detail.htm?songId=35729104
# https://www.melon.com/song/detail.htm?songId=35454425
# https://www.melon.com/song/detail.htm?songId=35931532
# https://www.melon.com/song/detail.htm?songId=35546497
# https://www.melon.com/song/detail.htm?songId=34061322
# https://www.melon.com/song/detail.htm?songId=36079879
# https://www.melon.com/song/detail.htm?songId=36078776
# https://www.melon.com/song/detail.htm?songId=36078780
# https://www.melon.com/song/detail.htm?songId=36078779
# https://www.melon.com/song/detail.htm?songId=36078778
# https://www.melon.com/song/detail.htm?songId=34908740
# ...

# %%
# for _ in total:
#     r = BeautifulSoup(requests.get("https://www.melon.com/song/detail.htm?songId={}".format(_), headers = head).text)
r = BeautifulSoup(requests.get("https://www.melon.com/song/detail.htm?songId={}".format(total[0]), headers = head).text)

# %%
name = ""
name += BeautifulSoup(str(r.find("div", class_ = "song_name")).replace("곡명", "")).text.strip()
name += " - "
name += BeautifulSoup(str(r.find("div", class_ = "artist")).replace("곡명", "")).text.strip()
print(name)
f = open("./top100/{}.txt".format(name), "w")
f.write(BeautifulSoup(str(r.find("div", id = "d_video_summary")).replace("<br/>", "\n")).text.strip())
f.close()
# Out:
# Ditto - NewJeans

# %%
r = requests.get("https://www.ppomppu.co.kr/zboard/zboard.php?id=ppomppu")
bs = BeautifulSoup(r.text)
bs2 = bs.find("table", id='revolution_main_table').findAll("tr")

# %%
total = []
for idx, x in enumerate(bs2):
    try:
        print(idx, x.findAll("a")[-1].text)
        total.append(x.findAll("a")[-1].text)
    except:
        print(idx, "해당번호에는 데이터 없음")
# Out:
# 0 해당번호에는 데이터 없음
# 1 해당번호에는 데이터 없음
# 2 해당번호에는 데이터 없음
# 3 [필독] 제목에는 특수 문자 사용을 절대 금지합니다.- 2010년 2월 24일
# 4
# 뽐뿌게시판 업자신고 프로세스 개선 안내
#
# 5 해당번호에는 데이터 없음
# 6 [G마켓] 도브 바디워시 뷰티너리싱 2개 (10,780원/무료) 스클 10,470원
# 7 [G마켓] 도브 바디워시 뷰티너리싱 2개 (10,780원/무료) 스클 10,470원
# 8 해당번호에는 데이터 없음
# 9 [11번가] 로지텍 G502 X lightspeed 무선 마우스 (138,570원/무료)
# 10 [11번가] 로지텍 G502 X lightspeed 무선 마우스 (138,570원/무료)
# 11 해당번호에는 데이터 없음
# 12 [쿠팡] 삼성전자 리얼 메탈 양문형냉장고 644L RH62A504EB4(1,138,160원/무료)
# 13 [쿠팡] 삼성전자 리얼 메탈 양문형냉장고 644L RH62A504EB4(1,138,160원/무료)
# 14 해당번호에는 데이터 없음
# 15 [코스트코온라인몰] 보스 사운드링크 미니2 SE (169,900/무료)
# 16 [코스트코온라인몰] 보스 사운드링크 미니2 SE (169,900/무료)
# 17 해당번호에는 데이터 없음
# 18 [11번가] PS5 갓오브워라그나로크 번들 포함 (625,000원/무배)
# 19 [11번가] PS5 갓오브워라그나로크 번들 포함 (625,000원/무배)
# 20 해당번호에는 데이터 없음
# 21 [네이버] 애슐리 햄듬뿍 부대찌개 600g (5,990~/3,000)
# 22 [네이버] 애슐리 햄듬뿍 부대찌개 600g (5,990~/3,000)
# 23 해당번호에는 데이터 없음
# 24 [11번가] Apple 아이폰 14 Pro 자급제 128GB - 딥 퍼플 [MQ0G3KH/A] (1,340,440원/무료)
# ...

# %%
import re

total = []
for idx, x in enumerate(bs2):
    try:
#         print(idx, x.findAll("a")[-1].text)
        total.append(x.findAll("a")[-1].text)
    except:
        pass
#         print(idx, "해당번호에는 데이터 없음")
        

p = re.compile("([0-9]+[,][0-9]+)")


total2 = []
for x in list(set(total)):
    try:
        print(f"{x} -- {p.findall(x)[0]}" )
        total2.append(p.findall(x)[0])
    except:
        pass
# Out:
# [티몬] 농심 스낵 8봉 (새우깡/양파링/감자깡/자갈치 ) 외 베스트 조합 모음전 (8,900원~.무료) -- 8,900
# [테스트벨리] 갤럭시탭 s7 fe (489,840원/무료) -- 489,840
# [비타민마켓]롯데 프랑크 햄꼬지 5종혼합 30개구성 (22,960원/무료) -- 22,960
# [11번가] 이고 엑시노 6in1 240W GAN PD 고속 충전기(179,000원/무료) -- 179,000
# [11번가] 로지텍 G502 X lightspeed 무선 마우스 (138,570원/무료) -- 138,570
# [코스트코온라인몰] 보스 사운드링크 미니2 SE (169,900/무료) -- 169,900
# [쿠팡] 삼성전자 리얼 메탈 양문형냉장고 644L RH62A504EB4(1,138,160원/무료) -- 1,138
# 고려은단 비타민C 1000 + 쇼핑백, 180정, 1개 (16,190원) -- 16,190
# [위메프] 해피머니 5만원 (46,050/0) -- 46,050
# [롯데온] 데일리 세척사과 부사 정품 3kg (14,510원/무료) -- 14,510
# [티몬] 아이폰 강화유리필름 5매 (3,900/무료) -- 3,900
# [11번가] Apple 아이폰 14 Pro 자급제 128GB - 딥 퍼플 [MQ0G3KH/A] (1,340,440원/무료) -- 1,340
# [skylifeshop] LG전자 룸앤티비 FHD 스마트TV모니터 27인치 27TN600S (239,000원/무배) -- 239,000
# [네이버] 애슐리 햄듬뿍 부대찌개 600g (5,990~/3,000) -- 5,990
# [G마켓] 도브 바디워시 뷰티너리싱 2개 (10,780원/무료) 스클 10,470원 -- 10,780
# [11번가] PS5 갓오브워라그나로크 번들 포함 (625,000원/무배) -- 625,000
# (끌올) [G마켓] 구글 기프트코드 10만원 (90,000원/무료) -- 90,000
# ...

# %%
total3 = [int(x.replace(',', '')) for x in total2]
total3
# Out:
# [8900,
#  489840,
#  22960,
#  179000,
#  138570,
#  169900,
#  1138,
#  16190,
#  46050,
#  14510,
#  3900,
#  1340,
#  239000,
#  5990,
#  10780,
#  625000,
#  90000,
#  12900]
